# %%
# TASK2_a
n = 32
# H0 <= 85
# HA > 85
# z-Test Right Tailed
from scipy.stats import norm
mu = 85
alpha = 0.05
x_bar = 87.5
sigma = 2.1
z_stats = (x_bar - mu) / (sigma / (n)**0.5)
p_value = norm.sf(abs(z_stats))
z_crit = norm.ppf(1-alpha)

# %%
# Task1_b
print(z_crit)
# Out:
# 1.6448536269514722

# %%
# Task1_c
print(z_stats)
# Out:
# 6.734350297014738

# %%
# Task1_d
print(z_crit)
# Out:
# 1.6448536269514722

# %%
# Task1_e
p_value < alpha
# Out:
# True

# %%
-z_crit>z_stats >z_crit
# Out:
# False

# %%
# Reject the hypothesis means mean average  throwing distance of Mac is more than 85 yards

# %%
import numpy as np

# %%
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)

# Compute corresponding y values for normal distribution
y = norm.pdf(x, mu, sigma)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue', label='Normal Distribution')
plt.title("Normal Distribution Curve")
plt.xlabel("Value")
plt.ylabel("Probability Density")
plt.grid(True)
plt.legend()
plt.show()
